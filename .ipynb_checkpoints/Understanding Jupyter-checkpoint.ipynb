# %%
# !python --version
# Out:
# Python 3.9.7

# %%
# %pwd
# Out:
# 'C:\\Users\\Kwadwo Amedi\\Documents\\Files\\Python Data Analysis\\Python Project\\first-python-analytics-solution'

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 00E2-2D82
#
#  Directory of C:\Users\Kwadwo Amedi\Documents\Files\Python Data Analysis\Python Project\first-python-analytics-solution
#
# 01/01/2022  10:47 pm    <DIR>          .
# 01/01/2022  10:25 pm    <DIR>          ..
# 01/01/2022  10:47 pm    <DIR>          .ipynb_checkpoints
# 01/01/2022  10:21 pm    <DIR>          dataset
# 01/01/2022  10:47 pm                72 Untitled.ipynb
#                1 File(s)             72 bytes
#                4 Dir(s)  414,869,319,680 bytes free

# %%
import matplotlib as plt

plt.__version__
# Out:
# '3.4.3'

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %cd
# Out:
# C:\Users\Kwadwo Amedi

# %%
# %env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\Kwadwo Amedi\\AppData\\Roaming',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'DESKTOP-IMG835E',
#  'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#  'CONDA_DEFAULT_ENV': 'base',
#  'CONDA_EXE': 'C:\\Users\\Kwadwo Amedi\\anaconda3\\Scripts\\conda.exe',
#  'CONDA_PROMPT_MODIFIER': '(base) ',
#  'CONDA_PYTHON_EXE': 'C:\\Users\\Kwadwo Amedi\\anaconda3\\python.exe',
#  'CONDA_SHLVL': '1',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\Kwadwo Amedi',
#  'LOCALAPPDATA': 'C:\\Users\\Kwadwo Amedi\\AppData\\Local',
#  'LOGONSERVER': '\\\\DESKTOP-IMG835E',
#  'NUMBER_OF_PROCESSORS': '8',
#  'ONEDRIVE': 'C:\\Users\\Kwadwo Amedi\\OneDrive',
#  'ONEDRIVECONSUMER': 'C:\\Users\\Kwadwo Amedi\\OneDrive',
#  'OS': 'Windows_NT',
#  'PATH': 'C:\\Users\\Kwadwo Amedi\\anaconda3;C:\\Users\\Kwadwo Amedi\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\Kwadwo Amedi\\anaconda3\\Library\\usr\\bin;C:\\Users\\Kwadwo Amedi\\anaconda3\\Library\\bin;C:\\Users\\Kwadwo Amedi\\anaconda3\\Scripts;C:\\Users\\Kwadwo Amedi\\anaconda3\\bin;C:\\Users\\Kwadwo Amedi\\anaconda3\\condabin;C:\\Users\\Kwadwo Amedi\\anaconda3;C:\\Users\\Kwadwo Amedi\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\Kwadwo Amedi\\anaconda3\\Library\\usr\\bin;C:\\Users\\Kwadwo Amedi\\anaconda3\\Library\\bin;C:\\Users\\Kwadwo Amedi\\anaconda3\\Scripts;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0;C:\\Windows\\System32\\OpenSSH;C:\\Users\\Kwadwo Amedi\\AppData\\Local\\Programs\\Python\\Python310\\Scripts;C:\\Users\\Kwadwo Amedi\\AppData\\Local\\Programs\\Python\\Python310;C:\\Users\\Kwadwo Amedi\\AppData\\Local\\Microsoft\\WindowsApps;.',
#  'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#  'PROCESSOR_ARCHITECTURE': 'AMD64',
#  'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 140 Stepping 2, GenuineIntel',
#  'PROCESSOR_LEVEL': '6',
#  'PROCESSOR_REVISION': '8c02',
#  'PROGRAMDATA': 'C:\\ProgramData',
#  'PROGRAMFILES': 'C:\\Program Files',
#  'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#  'PROGRAMW6432': 'C:\\Program Files',
#  'PROMPT': '(base) $P$G',
#  'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\Windows\\system32\\WindowsPowerShell\\v1.0\\Modules',
#  'PUBLIC': 'C:\\Users\\Public',
#  'SESSIONNAME': 'Console',
#  'SYSTEMDRIVE': 'C:',
#  'SYSTEMROOT': 'C:\\Windows',
#  'TEMP': 'C:\\Users\\KWADWO~1\\AppData\\Local\\Temp',
#  'TMP': 'C:\\Users\\KWADWO~1\\AppData\\Local\\Temp',
#  'USERDOMAIN': 'DESKTOP-IMG835E',
#  'USERDOMAIN_ROAMINGPROFILE': 'DESKTOP-IMG835E',
#  'USERNAME': 'Kwadwo Amedi',
#  'USERPROFILE': 'C:\\Users\\Kwadwo Amedi',
#  'WINDIR': 'C:\\Windows',
#  'ZES_ENABLE_SYSMAN': '1',
#  'CONDA_PREFIX': 'C:\\Users\\Kwadwo Amedi\\anaconda3',
#  'CONDA_ROOT': 'C:\\Users\\Kwadwo Amedi\\anaconda3',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'JPY_INTERRUPT_EVENT': '3180',
#  'IPY_INTERRUPT_EVENT': '3180',
#  'JPY_PARENT_PID': '3176',
#  'TERM': 'xterm-color',
#  'CLICOLOR': '1',
#  'PAGER': 'cat',
#  'GIT_PAGER': 'cat',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
def square(x):
    return x ** 2

for i in range(1, 4):
    print("square of %s is"%i, square(i))
# Out:
# square of 1 is 1
# square of 2 is 4
# square of 3 is 9

# %%
a = "this is a string"
b = 23

# %%
# %who int
# Out:
# b	 i

# %%
# %who str
# Out:
# a

# %%
# %rerun
# Out:
# === Executing: ===
# %who str
# === Output: ===
# a

# %%
string = "I want to pass this string to a different %notebook "

# %%
# %store string

del string
# Out:
# Stored 'string' (str)

# %%
# %%markdown
#
# This is a comment
# Out:
# This is a comment

# %%
# %%time

import time
for i in range(1000):
    time.sleep(0.01)
# Out:
# Wall time: 16.3 s

# %%
# %%timeit 

list_num = [n ** 2 for n in range(1000)]
# Out:
# 623 µs ± 17 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%writefile newfile.py

print('hi')
# Out:
# Writing newfile.py

# %%
# %run newfile.py
# Out:
# hi

# %%
# %%html
# <font size = 6 color = 'red'>
# Samuel Amedi
# </font>
# Out:
# <font size = 6 color = 'red'>
# Samuel Amedi
# </font>

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10)
line, = plt.plot(x, np.cos(x), '--', linewidth= 3)
# Out:
# <img src="data:image/png;base64,..." width="640">
